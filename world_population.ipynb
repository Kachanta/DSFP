# %% [markdown]
# <a href="https://colab.research.google.com/github/Kachanta/DSFP/blob/main/world_population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WORLD POPULATION ANALYSIS**
# ANALYSIS WORKFLOW:
# 1. Data Extraction and Webscraping
# 2. Data Cleaning
# 3. EDA
# 4. ANALYSIS
#   1. identify countries with high population & low population
#   2. identify the population growth rates
#   3. identify sources of the population information
#   4. identify countries with the most upto date data
#
# OBJECTIVE:
# 1.

# %%
# Importing relevant packages
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd
import urllib.request as urequest

# %% [markdown]
# # Data Extraction (Webscraping)

# %%
url = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

# %%
request = urequest.Request(url)

# %%
response = urequest.urlopen(request)

# %%
pop_data = response.read()
print(pop_data)
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of countries and dependencies by population - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-f
# ...

# %%
page = soup(pop_data, "html.parser")

# %%
print(page)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries and dependencies by population - Wikipedia</title>
# ...

# %%
data =page.find_all(class_='wikitable')
# data=page.find_all('class':'wikitable')

#conver the first table to dataframe
if data:
    table =data[0] #Acess the first table
    df=pd.read_html(str(table))
# Out:
# <ipython-input-35-a32afe23059b>:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df=pd.read_html(str(table))

# %%
type(df)
# Out:
# list

# %%
import numpy as np
df=np.array(df)

# %%
dff = df.copy()

# %%
dff=pd.DataFrame(dff.reshape(-1,7))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-bddadf5bd7e9> in <cell line: 1>()
# ----> 1 dff=pd.DataFrame(dff.reshape(-1,7))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %% [markdown]
# # Data Cleaning

# %%
dff.head()
# Out:
#          0              1           2      3            4  \
# 0        –          World  8119000000   100%   1 Jul 2024
# 1  1/2 [b]          China  1409670000  17.3%  31 Dec 2023
# 2  1/2 [b]          India  1404910000  17.2%   1 Jul 2024
# 3        3  United States   340110988   4.2%   1 Jul 2024
# 4        4      Indonesia   282477584   3.5%  30 Jun 2024
#
#                                5    6
# 0            UN projection[1][3]  NaN
# 1           Official estimate[5]  [c]
# 2         Official projection[6]  [d]
# 3           Official estimate[7]  [e]
# 4  National annual projection[8]  NaN

# %%
# Dropping some columns not relevant to our objective
dff.drop(columns = [0,6],axis=0,inplace=True)

# %%
dff.shape
# Out:
# (240, 5)

# %%
# Renaming the Column headers
cols = ["lacation","population","% of world","date","source"]
dff.columns =cols

# %%
dff.head()
# Out:
#         lacation  population % of world         date  \
# 0          World  8119000000       100%   1 Jul 2024
# 1          China  1409670000      17.3%  31 Dec 2023
# 2          India  1404910000      17.2%   1 Jul 2024
# 3  United States   340110988       4.2%   1 Jul 2024
# 4      Indonesia   282477584       3.5%  30 Jun 2024
#
#                           source
# 0            UN projection[1][3]
# 1           Official estimate[5]
# 2         Official projection[6]
# 3           Official estimate[7]
# 4  National annual projection[8]

# %%
# checking for null values
dff.isnull().sum()
# Out:
# lacation      0
# population    0
# % of world    0
# date          0
# source        0
# dtype: int64

# %%
#checking of duplicates
dff.duplicated().sum()
# Out:
# 0

# %%
dff['source'].nunique()
# Out:
# 234
